# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %%
# Ploting 12 image to checking dataset 
plt.figure(figsize=(12, 12))
path = '/content/drive/MyDrive/Colab Notebooks/Datasets/AMERICAN GOLDFINCH'
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %%
dir = '/content/drive/MyDrive/Colab Notebooks/Datasets'
root_dir = listdir(dir)
image_list, label_list = [], []

# %%
# Reading and converting image to numpy array 
for directory in root_dir:
  for files in listdir(f'{dir}/{directory}'):
    image_path = f'{dir}/{directory}/{files}'
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %%
# Visualize the number of class count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# dtype: int64

# %%
# Storing number of class
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %%
# Checking Labels shape 
label_list = np.array(label_list)
label_list.shape
# Out:
# (811,)

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
# Normalize and reshape data 
x_train = np.array(x_train, dtype = np.float16) / 225.0
x_test = np.array(x_test, dtype = np.float16) / 225.0
x_train = x_train.reshape(-1, 224, 224, 3)
x_test = x_test.reshape(-1, 224, 224, 3)

# %%
# Label binarizing 
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %%
# Spliting the training data set into training and validation datasets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %%
# Building model architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 224, 224, 8)       224
#
#  max_pooling2d_3 (MaxPooling  (None, 74, 74, 8)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 74, 74, 16)        1168
#
#  max_pooling2d_4 (MaxPooling  (None, 37, 37, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_5 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 10368)             0
#
#  dense_2 (Dense)             (None, 32)                331808
#
#  dense_3 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 338,038
# Trainable params: 338,038
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling model 
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005), metrics=['accuracy'])

# %%
# Training the model 
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 21s 4s/step - loss: 1.7475 - accuracy: 0.2181 - val_loss: 1.6901 - val_accuracy: 0.2846
# Epoch 2/50
# 5/5 [==============================] - 14s 3s/step - loss: 1.6695 - accuracy: 0.2085 - val_loss: 1.6327 - val_accuracy: 0.4231
# Epoch 3/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.5834 - accuracy: 0.4942 - val_loss: 1.5456 - val_accuracy: 0.4538
# Epoch 4/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.4893 - accuracy: 0.4131 - val_loss: 1.3817 - val_accuracy: 0.5846
# Epoch 5/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.3136 - accuracy: 0.5656 - val_loss: 1.2950 - val_accuracy: 0.5154
# Epoch 6/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.1829 - accuracy: 0.6004 - val_loss: 1.1018 - val_accuracy: 0.6154
# Epoch 7/50
# 5/5 [==============================] - 15s 3s/step - loss: 1.0866 - accuracy: 0.6544 - val_loss: 1.0659 - val_accuracy: 0.6308
# Epoch 8/50
# 5/5 [==============================] - 20s 4s/step - loss: 1.0070 - accuracy: 0.6680 - val_loss: 1.0443 - val_accuracy: 0.6462
# Epoch 9/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.8781 - accuracy: 0.7143 - val_loss: 0.9601 - val_accuracy: 0.6846
# Epoch 10/50
# 5/5 [==============================] - 18s 3s/step - loss: 0.7819 - accuracy: 0.7471 - val_loss: 0.9200 - val_accuracy: 0.6385
# Epoch 11/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.7175 - accuracy: 0.7645 - val_loss: 0.8944 - val_accuracy: 0.7077
# Epoch 12/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.7286 - accuracy: 0.7568 - val_loss: 0.8467 - val_accuracy: 0.6846
# Epoch 13/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.7087 - accuracy: 0.7278 - val_loss: 0.7689 - val_accuracy: 0.6769
# Epoch 14/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.6518 - accuracy: 0.7780 - val_loss: 0.7113 - val_accuracy: 0.7692
# Epoch 15/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.5546 - accuracy: 0.8224 - val_loss: 0.6837 - val_accuracy: 0.7462
# Epoch 16/50
# 5/5 [==============================] - 22s 4s/step - loss: 0.4759 - accuracy: 0.8610 - val_loss: 0.6507 - val_accuracy: 0.7692
# Epoch 17/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.5010 - accuracy: 0.8456 - val_loss: 0.6945 - val_accuracy: 0.7385
# Epoch 18/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.4903 - accuracy: 0.8282 - val_loss: 0.6844 - val_accuracy: 0.7231
# Epoch 19/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.5270 - accuracy: 0.8320 - val_loss: 0.6017 - val_accuracy: 0.7769
# Epoch 20/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.3808 - accuracy: 0.8900 - val_loss: 0.6427 - val_accuracy: 0.7615
# Epoch 21/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.3518 - accuracy: 0.9151 - val_loss: 0.5272 - val_accuracy: 0.8154
# Epoch 22/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.3339 - accuracy: 0.9170 - val_loss: 0.5161 - val_accuracy: 0.8231
# Epoch 23/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.2929 - accuracy: 0.9421 - val_loss: 0.5266 - val_accuracy: 0.8231
# Epoch 24/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.2909 - accuracy: 0.9247 - val_loss: 0.4994 - val_accuracy: 0.8231
# Epoch 25/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.2569 - accuracy: 0.9344 - val_loss: 0.5994 - val_accuracy: 0.7769
# Epoch 26/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.2366 - accuracy: 0.9479 - val_loss: 0.5300 - val_accuracy: 0.7846
# Epoch 27/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.2229 - accuracy: 0.9479 - val_loss: 0.5092 - val_accuracy: 0.8154
# Epoch 28/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.2048 - accuracy: 0.9517 - val_loss: 0.5266 - val_accuracy: 0.8000
# Epoch 29/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.1859 - accuracy: 0.9537 - val_loss: 0.5086 - val_accuracy: 0.8000
# Epoch 30/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.1917 - accuracy: 0.9633 - val_loss: 0.5288 - val_accuracy: 0.8154
# Epoch 31/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.1803 - accuracy: 0.9537 - val_loss: 0.5043 - val_accuracy: 0.8077
# Epoch 32/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.1814 - accuracy: 0.9575 - val_loss: 0.4871 - val_accuracy: 0.8154
# Epoch 33/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.1599 - accuracy: 0.9653 - val_loss: 0.4900 - val_accuracy: 0.8538
# Epoch 34/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.1384 - accuracy: 0.9807 - val_loss: 0.5199 - val_accuracy: 0.8231
# Epoch 35/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.1348 - accuracy: 0.9730 - val_loss: 0.4784 - val_accuracy: 0.8538
# Epoch 36/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.1234 - accuracy: 0.9807 - val_loss: 0.4381 - val_accuracy: 0.8538
# Epoch 37/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.1070 - accuracy: 0.9865 - val_loss: 0.4599 - val_accuracy: 0.8462
# Epoch 38/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0977 - accuracy: 0.9865 - val_loss: 0.4721 - val_accuracy: 0.8077
# Epoch 39/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.1218 - accuracy: 0.9614 - val_loss: 0.4711 - val_accuracy: 0.8231
# Epoch 40/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0998 - accuracy: 0.9826 - val_loss: 0.5302 - val_accuracy: 0.8154
# Epoch 41/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.1362 - accuracy: 0.9595 - val_loss: 0.5102 - val_accuracy: 0.8154
# Epoch 42/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.1037 - accuracy: 0.9768 - val_loss: 0.4490 - val_accuracy: 0.8385
# Epoch 43/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0966 - accuracy: 0.9749 - val_loss: 0.4592 - val_accuracy: 0.8385
# Epoch 44/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0773 - accuracy: 0.9884 - val_loss: 0.4465 - val_accuracy: 0.8769
# Epoch 45/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0707 - accuracy: 0.9884 - val_loss: 0.5052 - val_accuracy: 0.8154
# Epoch 46/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.0637 - accuracy: 0.9961 - val_loss: 0.4530 - val_accuracy: 0.8308
# Epoch 47/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0548 - accuracy: 0.9961 - val_loss: 0.4292 - val_accuracy: 0.8462
# Epoch 48/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0657 - accuracy: 0.9903 - val_loss: 0.4749 - val_accuracy: 0.8231
# Epoch 49/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0641 - accuracy: 0.9961 - val_loss: 0.4740 - val_accuracy: 0.8385
# Epoch 50/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0663 - accuracy: 0.9923 - val_loss: 0.4772 - val_accuracy: 0.8462

# %%
# Saving model 
model.save('/content/drive/MyDrive/bird_species.h5')

# %%
# Plot the training history 
plt.figure(figsize=(12,5))
plt.plot(history.history['accuracy'], color = 'r')
plt.plot(history.history['val_accuracy'], color = 'b')
plt.title('Model Accuracy')
plt.xlabel('Accuracy') 
plt.ylabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
# Plot the loss history 
plt.figure(figsize=(12,5))
plt.plot(history.history['loss'], color = 'r')
plt.plot(history.history['val_loss'], color = 'b')
plt.title('Model Loss')
plt.xlabel('Loss') 
plt.ylabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
# Calculating test accuracy 
score = model.evaluate(x_test, y_test)
print(f'Test Accuracy : {score[1]*100}')
# Out:
# 6/6 [==============================] - 2s 370ms/step - loss: 0.4668 - accuracy: 0.8282
# Test Accuracy : 82.82208442687988

# %%
# Storing predictions 
y_pred = model.predict(x_test)

# %%
# Ploting image to compare 
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9C8FC71650>

# %%
# Finding max value from prediction list and comaparing original value vs predicted 
labels = lb.classes_
print(labels)
print('Originally : ', labels[np.argmax(y_test[10])])
print('Prediction : ', labels[np.argmax(y_pred[10])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  BARN OWL
# Prediction :  EMPEROR PENGUIN

# %% [markdown]
# Garut, 22 Juli 2022
# Shopi Nurhidayanti
